# %%
import pandas as pd
data = pd.read_csv('C:/Users/Administrator/Documents/cars.csv', encoding='ISO-8859-1')

# %%
rows, columns = data.shape
print(f"Number of rows: {rows}")
print(f"Number of columns: {columns}")
# Out:
# Number of rows: 33
# Number of columns: 12

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('C:/Users/Administrator/Documents/cars.csv', encoding='ISO-8859-1')

# Calculate summary statistics for numeric columns
summary_stats = {
    "Mean": data.mean(numeric_only=True),
    "Median": data.median(numeric_only=True),
    "Standard Deviation": data.std(numeric_only=True)
}

# Convert to a DataFrame for better visualization
stats_df = pd.DataFrame(summary_stats)

# Display the summary statistics
print(stats_df)
# Out:
#             Mean   Median  Standard Deviation
# mpg    20.090625   19.200            6.026948
# cyl     6.187500    6.000            1.785922
# disp  230.721875  196.300          123.938694
# hp    146.687500  123.000           68.562868
# drat    3.596563    3.695            0.534679
# wt      3.217250    3.325            0.978457
# qsec   17.848750   17.710            1.786943
# vs      0.437500    0.000            0.504016
# am      0.406250    0.000            0.498991
# gear    3.687500    4.000            0.737804
# carb    2.812500    2.000            1.615200

# %%
percentiles = data.quantile([0.25, 0.75], numeric_only=True)

print(percentiles)
# Out:
#          mpg  cyl     disp     hp  drat       wt     qsec   vs   am  gear  \
# 0.25  15.425  4.0  120.825   96.5  3.08  2.58125  16.8925  0.0  0.0   3.0
# 0.75  22.800  8.0  326.000  180.0  3.92  3.61000  18.9000  1.0  1.0   4.0
#
#       carb
# 0.25   2.0
# 0.75   4.0

# %%
sns.displot(data=data, x='mpg', kde=True, bins=20, color='blue', height=50, aspect=1.5)

# %%
sns.boxplot(data=data, x='hp', color='green')
# Out:
# <AxesSubplot:xlabel='hp'>
